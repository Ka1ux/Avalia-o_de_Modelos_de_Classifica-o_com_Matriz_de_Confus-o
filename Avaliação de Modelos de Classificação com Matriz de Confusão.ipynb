# %%
# -*- coding: utf-8 -*-
"""Projeto: Avaliação de Modelos de Classificação
Descrição: Calcula matriz de confusão e métricas de avaliação (Acurácia, Precisão, Recall, F1-Score)
"""

# --- Importação das Bibliotecas ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# --- 1. Criação dos Dados de Exemplo ---
y_true = np.array([1]*45 + [0]*15 + [0]*35 + [1]*5)
y_pred = np.array([1]*45 + [1]*15 + [0]*35 + [0]*5)

classes = [0, 1]

# --- 2. Matriz de Confusão ---
con_mat = confusion_matrix(y_true, y_pred)
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm, index=classes, columns=classes)

plt.figure(figsize=(6,6))
sns.heatmap(con_mat_df, annot=True, cmap=plt.cm.Blues)
plt.ylabel('Rótulo Verdadeiro')
plt.xlabel('Rótulo Previsto')
plt.title("Matriz de Confusão Normalizada")
plt.show()

# --- 3. Cálculo das Métricas de Avaliação ---
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print("""
--- Métricas de Avaliação ---""")
print(f"Acurácia: {accuracy:.2f}")
print(f"Precisão: {precision:.2f}")
print(f"Revocação (Recall): {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# --- Métricas de Avaliação ---
# Acurácia: 0.80
# Precisão: 0.75
# Revocação (Recall): 0.90
# F1-Score: 0.82
